# %%
import os
import openai

client = openai.OpenAI(
    api_key=os.getenv("SWISS_AI_PLATFORM_API_KEY"),
    base_url="https://api.swisscom.com/layer/swiss-ai-weeks/apertus-70b/v1"
)

stream = client.chat.completions.create(
    model="swiss-ai/Apertus-70B",
    messages=[
        {"role": "system", "content": "You are a travel agent. Be descriptive and helpful"},
        {"role": "user", "content": "What are the best places to visit in Switzerland?"}
    ],
    stream=True
)

for chunk in stream:
    print(chunk.choices[0].delta.content or "", end="", flush=True)
# Out:
# Switzerland, a beautiful country nestled in the heart of the Alps is a winter paradise for skiers and a summer haven for hikers. Here are some of the best places to visit in Switzerland:
#
# 1. **Zermatt**: Known for its picturesque town and stunning views of the Matterhorn, the highest mountain in the Swiss Alps. It is also a world-renowned ski resort with excellent ski slopes and a plethora of mountain activities.
#
# 2. **Geneva**: A global city and a major financial center, Geneva is also famous for its stunning lake, the Jet d'Eau fountain, and being the headquarters of various international organizations like the United Nations and the Red Cross.
#
# 3. **Interlaken**: Perfect for outdoor enthusiasts, Interlaken offers breathtaking views of the nearby mountains. It's a hub for adventure sports like paragliding, rafting, and hiking.
#
# 4. **Lucerne**: A medieval town set on the shores of Lake Lucerne, close to the Rigi and Pilatus mountains. The Chapel Bridge and Musegg Wall are must-visit attractions here.
#
# 5. **Bern**: The Swiss capital is a historic city with well-preserved medieval architecture, including the famous Zytglogge clock tower and the bear park.
#
# 6. **St. Moritz**: This upscale resort town in the Engadine Valley has hosted the Winter Olympics twice and is known for its luxurious hotels, pristine ski slopes, and the beautiful Engadine Valley.
#
# 7. **Lake Geneva (Lac Léman)**: The largest lake in Switzerland offers stunning beauty, with picturesque towns and villages along its shores, like Vevey, Montreux and Lausanne.
#
# 8. **Zurich**: Switzerland's largest city and a hub for international banking and finance. It has a rich cultural scene, with the Kunsthaus and the opera house. Zurich's Old Town and Bahnhofstrasse (one of the world's most expensive shopping streets) are not to be missed.
#
# 9. **Jungfraujoch aka "Top of Europe"**: This is the highest train station in Europe, offering panoramic views of the Swiss Alps. It's a must-visit for any mountainous scenery enthusiast.
#
# 10. **Rhine Falls**: While they're not in the Alps, they are the largest waterfall in Europe and a spectacular natural wonder. They're easy to visit on a day trip from Zurich or other Swiss cities.
#
# 11. **Grindelwald**: Another popular ski resort in the Swiss Alps known for its picturesque mountain scenery. It's often visited as part of a long-distance route known as the Eiger Route.
#
# 12. **Zug**: This town is well-known for its picturesque old town, Zug Castle, and Lake Zug. It also offers excellent skiing opportunities, with Stoos and Hoch-Ybrig nearby.
#
# 13. **Neuchâtel and the Lake**: This beautiful university town has a charming old town and lake with a picturesque castle.
#
# 14. **Schaffhausen and the Rhine Falls**: This charming town is located at the northern tip of Switzerland, just minutes from the Rhine Falls.
#
# 15. **Lauterbrunnen Valley**: Known for its picturesque village and stunning mountain landscapes.
#
# Each of these locations has something unique to offer, and the best places for you would depend on your interests, travel style, and the time of year when you're planning your trip. Whether you're looking for adventure, history, culture, nature, or relaxation, Switzerland has it all.
#
# Before planning your trip, I recommend considering the season, as various attractions and activities are better suited to different times of the year. For example, the winter months are ideal for skiing, while summer is perfect for hiking, mountaineering, and exploring the lakes.
