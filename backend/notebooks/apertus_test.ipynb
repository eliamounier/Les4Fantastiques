self-assertion.'''

# %%
system_prompt = f"""
You are a patient education assistant fluent in many languages who rewrites book passages so learners can read with comfort and joy.

TARGET LEVEL: {LEVEL} (CEFR)

CORE RULES (apply all):
- Preserve all facts, names, places, dates, and event sequences exactly
- Do NOT add events, characters, or details not in the original
- Maintain a friendly, engaging narrative voice
- Simplify syntax and vocabulary to match {LEVEL} precisely
- Keep original paragraph structure
- Avoid bullet lists unless in the source text
- Explain up to 5 challenging words inline: (word: brief definition) - first occurrence only
- Signal any omissions with [...] - keep minimal
- Preserve proper nouns unchanged
- Maintain the emotional tone and intent of any dialogue or quotes

LEVEL-SPECIFIC GUIDELINES:
- A2: Simple sentences (8-12 words max), basic connectors (and, but, so, then), only high-frequency vocabulary (1000 most common words)
- B1: Mix of simple and compound sentences, everyday vocabulary, clear time/cause connectors (because, when, after, before)
- B2: Varied sentence structures, some abstract concepts allowed, natural flow with sophisticated connectors
- C1: Complex ideas expressed clearly, figurative language preserved when essential, rich but accessible vocabulary
- C2: Near-original sophistication with subtle clarifications, preserve literary style and nuance

OUTPUT: Provide only the simplified text without meta-commentary.
"""

# %%
user_prompt = f"""
I have {LEVEL} level {LANGUAGE}. Please simplify this passage into a friendly, story-like narrative.

{f'''CONTEXT FROM PREVIOUS SECTION:
{PAST_CHUNK}

Use this only for continuity - do not repeat or rewrite this content.
''' if PAST_CHUNK else ''}

TEXT TO SIMPLIFY:
{CURRENT_TEXT}
"""

# %%
import os
import openai

client = openai.OpenAI(
    api_key=os.getenv("SWISS_AI_PLATFORM_API_KEY"),
    base_url="https://api.swisscom.com/layer/swiss-ai-weeks/apertus-70b/v1"
)

stream = client.chat.completions.create(
    model="swiss-ai/Apertus-70B",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    stream=True
)

for chunk in stream:
    print(chunk.choices[0].delta.content or "", end="", flush=True)
# Out:
# On May 3rd, I left Munich at 8:35 PM on May 1st and arrived in Vienna early the next morning—about an hour late. A quick look through the streets while in Buda-Pesth (a part of modern-day Budapest) showed me a mixture of Western and Eastern worlds. There was a grand Danube River, but the train was held up, so I didn’t roam far, keeping close to the station to stay on schedule for the next leg.
#
# I stopped in Klausenburgh (now known as Cluj-Napoca in Romania) for the night at the Hotel Royale. My dinner was a chicken dish called “paprika hendl.” It was delicious but made me very thirsty. I found my little German quite useful here because it was a national dish and common along the Carpathian mountains.
#
# Before this trip, I dug around in the British Museum to learn about Transylvania. I discovered it’s a place with mixed cultures—like the Saxons in the South, mixed with Wallachs, who are descendants of the ancient Dacians; the Magyars to the West, and Szekelys to the East and North. The Szekelys say they come from Attila the Hun, though it’s debated, but historically, the Magyars did find the Huns here in the 11th century.
#
# Transylvania, we’re told, is the hub of many old superstitions in Europe—like an imaginative whirlpool of folklore. This adds to the interest of my journey to see Count Dracula.
#
# I didn’t sleep well, with dreams and a howling dog outside my window. Maybe the “paprika” was too spicy or maybe my nerves, but I was thirsty all night. Woken by a knock on the door (it must have been morning as I slept right through some noise by then), I had more “paprika hendl” for breakfast plus “mamaliga” and “impletata” (stuffed eggplant)—both very good but I had to rush to catch my 8 AM train. Trains, I noticed, become less on time the further East you go (what must they be like in China?).
#
# Our train dawdled through gorgeous countryside with medieval-looking towns perched on hilltops and rivers that hinted at being prone to big floods. Every station was a bustle of people in varied traditional wear—some like back home in rural Europe and others, like Slovaks with their striking look (big hats, roomy trousers, and wide studded belts), were really eye-catching but quite rough around the edges. It was a mix of the familiar and strange.
#
# These notes should help me talk about my journey with Mina. The mix of cultures and stranger things like superstitions and folklore create a lively backdrop for my mission to see the mysterious Count Dracula.
