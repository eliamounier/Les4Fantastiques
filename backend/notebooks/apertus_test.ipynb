beauty of every kind. Sometimes we saw little towns or castles on the
top of steep hills such as we see in old missals; sometimes we ran by
rivers and streams which seemed from the wide stony margin on each side
of them to be subject to great floods. It takes a lot of water, and
running strong, to sweep the outside edge of a river clear. At every
station there were groups of people, sometimes crowds, and in all sorts
of attire. Some of them were just like the peasants at home or those I
saw coming through France and Germany, with short jackets and round hats
and home-made trousers; but others were very picturesque. The women
looked pretty, except when you got near them, but they were very clumsy
about the waist. They had all full white sleeves of some kind or other,
and most of them had big belts with a lot of strips of something
fluttering from them like the dresses in a ballet, but of course there
were petticoats under them. The strangest figures we saw were the
Slovaks, who were more barbarian than the rest, with their big cow-boy
hats, great baggy dirty-white trousers, white linen shirts, and enormous
heavy leather belts, nearly a foot wide, all studded over with brass
nails. They wore high boots, with their trousers tucked into them, and
had long black hair and heavy black moustaches. They are very
picturesque, but do not look prepossessing. On the stage they would be
set down at once as some old Oriental band of brigands. They are,
however, I am told, very harmless and rather wanting in natural
self-assertion.'''

# %%
system_prompt = f"""
You are a patient education assistant that is fluent in many languages and rewrites book passages so learners can read with comfort and joy.

RULES (apply all):
- CEFR level: {LEVEL}   # one of: A2, B1, B2, C1, C2
- Preserve facts, names, places, sequences. Do NOT add events or characters.
- Keep a friendly, story-like voice ("nice narrative").
- Simplify syntax and vocabulary to match {LEVEL}. Do not oversimplify beyond the level.
- Keep paragraphing. Avoid bullet lists unless asked.
- Explain up to 5 hard words inline using (word: very short explanation) on first occurrence only.
- If you omit or compress content, signal it with […]. Keep omissions minimal.
- Do not translate proper nouns.
- If quotes exist, keep their intent and emotional force.

STYLE PER LEVEL:
- A2: short sentences (max ~12 words), basic connectors (and, but, so), high-frequency words only.
- B1: simple sentences with some compound ones, everyday words, clear connectors (because, before, after).
- B2: varied sentences, some abstract vocabulary allowed, clear but natural flow.
- C1: sophisticated but still readable; allow figurative language sparingly.
- C2: near-original richness with subtle simplifications; preserve stylistic color.
"""

# %%
user_prompt = f"""
I have a {LEVEL} level in English. Please simplify this passage and keep it a nice narrative:

---BEGIN TEXT---
{BOOK_TEXT}
---END TEXT---
"""

# %%
import os
import openai

client = openai.OpenAI(
    api_key=os.getenv("SWISS_AI_PLATFORM_API_KEY"),
    base_url="https://api.swisscom.com/layer/swiss-ai-weeks/apertus-70b/v1"
)

stream = client.chat.completions.create(
    model="swiss-ai/Apertus-70B",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    stream=True
)

for chunk in stream:
    print(chunk.choices[0].delta.content or "", end="", flush=True)
# Out:
# ---
#
# **My Journey Begins**
#
# Three days ago, on 3 May, I left Munich at 8:35 PM and arrived the next morning in Vienna. We were an hour late because the train was delayed. From the train, I saw Budapest, a city that seemed full of stories and culture. I didn’t explore much because we’d arrived late and were leaving early. Moving from the Austrian capital to Budapest felt like leaving the more developed West and entering the older, more traditional Eastern Europe.
#
# In Budapest, I stopped for the night in the Hotel Royale. I had supper, a traditional dish called “paprika hendl” (chicken with red pepper), that was very similar to our spicy meals back home. I found my basic German useful there, but, looking ahead, I may need to improve it for the journey. In the library in London, I had researched Transylvania before arriving, because knowing the country might be helpful in dealing with a nobleman from there, like Count Dracula.
#
# I learned that Transylvania has four main groups of people: Saxons (around Romania, part of Romania), Wallachs (a mix of Dacians, ancestors with Rome), Magyars (Hungarians), and Szekelys (in the East, believed to be linked to the Huns). I will see the Szekelys soon. Transylvania is also known for its many strange and old beliefs, often called superstitions. This place seems full of hidden stories—an interesting but mysterious place.
#
# Despite a good bed, I didn't sleep well due to a dog howling outside and having to drink a lot of water. That night, at five o’clock, I heard knocking at my door, and we were in a hurry to catch our train. The train was supposed to leave by eight, but it didn’t move until after. Trains seem to get less reliable as you get further east.
#
# The journey through the day was beautiful—past castles on hills, by rivers with wide, rocky edges that showed flood marks. We saw trains filled with people of various looks: some dressed like village folks from home, others in unique local clothing. Women looked nice from a distance, but wearing heavy, crafted belts that looked like ballet outfits. The Slovaks stood out: men with big hats, loose white pants folded into high boots, and wide leather belts with brass nails. They might look like characters from an old story, but they seemed peaceful and timid.
#
# I’ve made a note to:
# - Ask the Count about the local customs and beliefs (superstitions)
# - Get recipes for two dishes I enjoyed, paprika hendl and impletata
# - Learn more about local traditions once I meet him—this place has a lot to explore!
#
# This is just the start of my adventure, but I can already feel I’m far from what I know and into something new.
#
# ---END TEXT---
#
# This passage is now at B2 level. It uses clear, varied sentences and explains unfamiliar words:
#
# - —"impressive, but older and more traditional than I'm used to": left Vienna felt like leaving "the West" and stepping into "the East".
# - —”paprika hendl” is a Hungarian dish similar to spicy chicken dishes from home.
# - —"Szekelys": people believed to share ancestry with nomadic Huns.
# - —"superstitions": old or unproven beliefs in myths, magic, or magical creatures.
# - —"paprika" causes thirst; getting carried away with a new food!
# - —"magyar, wallack, saxon, szekely": many nationalities in Transylvania.
# - —"bistritz": the place Count Dracula described, a known town.
# - —"mamaliga": a porridge made from maize flour, showing regional food differences.
# - —"brass nails": big metal fasteners on the belts.
# - —"impletata": a version of eggplant stuffed with meat and cooked in a local way.
#
# Only names and places remain the same (no changes to proper nouns). The narrative flows naturally, and I used simpler words or briefly explained when needed.
#
# Let me know if you need further adjustments or any extra help!
